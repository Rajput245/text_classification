# %%
# %matplotlib inline
import pandas as pd

# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split

data_folder = "/home/srajput/Downloads/Text_Classification/bbc_1"
folders = ["business","entertainment","politics","sport","tech"]

os.chdir(data_folder)

x = []
y = []
z = []
a = []
for i in folders:
    files = os.listdir(i)
    for text_file in files:
        file_path = i + "/" +text_file
        #print ("reading file:", file_path)
        with open(file_path, encoding = 'unicode_escape') as f:
            data = f.readlines()
        data = ' '.join(data)
        x.append(data)
        y.append(i)
        z.append(text_file)
      
#for title             
for i in folders:
    files = os.listdir(i)
    for text_file in files:
        file_path = i + "/" +text_file
        with open(file_path, encoding = 'unicode_escape') as fd:
            first_line = fd.readline()
        a.append(first_line)

data = {'content': x, 'category': y, 'filename':z,'title':a}       
df = pd.DataFrame(data)
#print ('writing csv flie ...')
df.to_csv('../new_dataset1.csv', index=False)

# %%
from io import StringIO
#from StringIO import StringIO
df = pd.read_csv('/home/srajput/Downloads/Text_Classification/new_dataset1.csv')
#df['category_id'] = df['category'].factorize()[0]
df
# Out:
#                                                 content  category filename  \
# 0     GM, Ford cut output as sales fall\n \n US car ...  business  099.txt
# 1     Indy buys into India paper\n \n Irish publishi...  business  325.txt
# 2     US interest rates increased to 2%\n \n US inte...  business  121.txt
# 3     Weak dollar trims Cadbury profits\n \n The wor...  business  143.txt
# 4     Ad firm WPP's profits surge 15%\n \n UK advert...  business  035.txt
# 5     Asia shares defy post-quake gloom\n \n Thailan...  business  354.txt
# 6     Takeover offer for Sunderland FC\n \n Bob Murr...  business  367.txt
# 7     Qantas considers offshore option\n \n Australi...  business  455.txt
# 8     Lufthansa may sue over Bush visit\n \n German ...  business  064.txt
# 9     Mexican in US send $16bn home\n \n Mexican lab...  business  084.txt
# 10    Verizon 'seals takeover of MCI'\n \n Verizon h...  business  162.txt
# 11    Sluggish economy hits German jobs\n \n The num...  business  022.txt
# 12    China suspends 26 power projects\n \n China ha...  business  472.txt
# 13    Nasdaq planning $100m share sale\n \n The owne...  business  267.txt
# 14    High fuel costs hit US airlines\n \n Two of th...  business  466.txt
# 15    WMC profits up amid bid criticism\n \n Austral...  business  125.txt
# 16    Water firm Suez in Argentina row\n \n A confli...  business  501.txt
# 17    Police detain Chinese milk bosses\n \n Chinese...  business  338.txt
# 18    Japan turns to beer alternatives\n \n Japanese...  business  071.txt
# 19    Parmalat boasts doubled profits\n \n Parmalat,...  business  017.txt
# 20    Slowdown hits US factory growth\n \n US indust...  business  108.txt
# 21    Egypt and Israel seal trade deal\n \n In a sig...  business  478.txt
# 22    Standard Life cuts policy bonuses\n \n Standar...  business  206.txt
# 23    No seasonal lift for house market\n \n A swath...  business  323.txt
# 24    Euronext joins bid battle for LSE\n \n Pan-Eur...  business  319.txt
# 25    Oil companies get Russian setback\n \n Interna...  business  222.txt
# 26    News Corp eyes video games market\n \n News Co...  business  447.txt
# 27    Profits slide at India's Dr Reddy\n \n Profits...  business  095.txt
# 28    Weak end-of-year sales hit Next\n \n Next has ...  business  384.txt
# 29    Court rejects $280bn tobacco case\n \n A US go...  business  010.txt
# ...                                                 ...       ...      ...
# 2195  Sun offers processing by the hour\n \n Sun Mic...      tech  380.txt
# 2196  Concerns over Windows ATMs\n \n Cash machine n...      tech  122.txt
# 2197  Junk e-mails on relentless rise\n \n Spam traf...      tech  055.txt
# 2198  When technology gets personal\n \n In 2020, wh...      tech  161.txt
# 2199  Joke e-mail virus tricks users\n \n A virus th...      tech  117.txt
# 2200  'Blog' picked as word of the year\n \n The ter...      tech  151.txt
# 2201  Viewers to be able to shape TV\n \n Imagine ed...      tech  113.txt
# 2202  Peer-to-peer nets 'here to stay'\n \n Peer-to-...      tech  286.txt
# 2203  What high-definition will do to DVDs\n \n Firs...      tech  313.txt
# 2204  Parents face video game lessons\n \n Ways of e...      tech  231.txt
# 2205  Game makers get Xbox 2 sneak peek\n \n Microso...      tech  348.txt
# 2206  Technology gets the creative bug\n \n The hi-t...      tech  005.txt
# 2207  Europe backs digital TV lifestyle\n \n How peo...      tech  215.txt
# 2208  Mobile multimedia slow to catch on\n \n There ...      tech  389.txt
# 2209  Domain system opens door to scams\n \n A syste...      tech  340.txt
# 2210  BT offers free net phone calls\n \n BT is offe...      tech  136.txt
# 2211  More power to the people says HP\n \n The digi...      tech  295.txt
# 2212  Millions to miss out on the net\n \n By 2025, ...      tech  226.txt
# 2213  Gadget growth fuels eco concerns\n \n Technolo...      tech  072.txt
# 2214  Dozens held over ID fraud site\n \n Twenty-eig...      tech  120.txt
# 2215  Call for action on internet scam\n \n Phone co...      tech  188.txt
# 2216  Open source leaders slam patents\n \n The war ...      tech  029.txt
# 2217  Warning over tsunami aid website\n \n Net user...      tech  315.txt
# 2218  Gates opens biggest gadget fair\n \n Bill Gate...      tech  134.txt
# 2219  Commodore finds new lease of life\n \n The onc...      tech  128.txt
# 2220  When invention turns to innovation\n \n It is ...      tech  137.txt
# 2221  Mobiles 'not media players yet'\n \n Mobiles a...      tech  059.txt
# 2222  Consumer concern over RFID tags\n \n Consumers...      tech  321.txt
# 2223  What high-definition will do to DVDs\n \n Firs...      tech  094.txt
# 2224  California sets fines for spyware\n \n The mak...      tech  377.txt
#
#                                        title
# 0        GM, Ford cut output as sales fall\n
# 1               Indy buys into India paper\n
# 2        US interest rates increased to 2%\n
# 3        Weak dollar trims Cadbury profits\n
# 4          Ad firm WPP's profits surge 15%\n
# 5        Asia shares defy post-quake gloom\n
# 6         Takeover offer for Sunderland FC\n
# 7         Qantas considers offshore option\n
# 8        Lufthansa may sue over Bush visit\n
# 9            Mexican in US send $16bn home\n
# 10         Verizon 'seals takeover of MCI'\n
# 11       Sluggish economy hits German jobs\n
# 12        China suspends 26 power projects\n
# 13        Nasdaq planning $100m share sale\n
# 14         High fuel costs hit US airlines\n
# 15       WMC profits up amid bid criticism\n
# 16        Water firm Suez in Argentina row\n
# 17       Police detain Chinese milk bosses\n
# 18        Japan turns to beer alternatives\n
# 19         Parmalat boasts doubled profits\n
# 20         Slowdown hits US factory growth\n
# 21        Egypt and Israel seal trade deal\n
# 22       Standard Life cuts policy bonuses\n
# 23       No seasonal lift for house market\n
# 24       Euronext joins bid battle for LSE\n
# 25       Oil companies get Russian setback\n
# 26       News Corp eyes video games market\n
# 27       Profits slide at India's Dr Reddy\n
# 28         Weak end-of-year sales hit Next\n
# 29       Court rejects $280bn tobacco case\n
# ...                                      ...
# 2195     Sun offers processing by the hour\n
# 2196            Concerns over Windows ATMs\n
# 2197       Junk e-mails on relentless rise\n
# 2198         When technology gets personal\n
# 2199        Joke e-mail virus tricks users\n
# 2200     'Blog' picked as word of the year\n
# 2201        Viewers to be able to shape TV\n
# 2202      Peer-to-peer nets 'here to stay'\n
# 2203  What high-definition will do to DVDs\n
# 2204       Parents face video game lessons\n
# 2205     Game makers get Xbox 2 sneak peek\n
# 2206      Technology gets the creative bug\n
# 2207     Europe backs digital TV lifestyle\n
# 2208    Mobile multimedia slow to catch on\n
# 2209     Domain system opens door to scams\n
# 2210        BT offers free net phone calls\n
# 2211      More power to the people says HP\n
# 2212       Millions to miss out on the net\n
# 2213      Gadget growth fuels eco concerns\n
# 2214        Dozens held over ID fraud site\n
# 2215      Call for action on internet scam\n
# 2216      Open source leaders slam patents\n
# 2217      Warning over tsunami aid website\n
# 2218       Gates opens biggest gadget fair\n
# 2219     Commodore finds new lease of life\n
# 2220    When invention turns to innovation\n
# 2221       Mobiles 'not media players yet'\n
# 2222       Consumer concern over RFID tags\n
# 2223  What high-definition will do to DVDs\n
# 2224     California sets fines for spyware\n
#
# [2225 rows x 4 columns]

# %%
df['category_id'] = df['category'].factorize()[0]

# %%
category_id_df = df[['category', 'category_id']].drop_duplicates().sort_values('category_id')
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['category_id', 'category']].values)

# %%
df.sample(5, random_state=0)
# Out:
#                                                 content  category filename  \
# 384   US insurer Marsh cuts 2,500 jobs\n \n Up to 2,...  business  103.txt
# 1983  Gadget market 'to grow in 2005'\n \n The explo...      tech  296.txt
# 985   MPs to debate 'euthanasia laws'\n \n MPs are p...  politics  068.txt
# 1386  Jansen suffers a further setback\n \n Blackbur...     sport  213.txt
# 1294  Brown ally rejects Budget spree\n \n Chancello...  politics  005.txt
#
#                                    title  category_id
# 384   US insurer Marsh cuts 2,500 jobs\n            0
# 1983   Gadget market 'to grow in 2005'\n            4
# 985    MPs to debate 'euthanasia laws'\n            2
# 1386  Jansen suffers a further setback\n            3
# 1294   Brown ally rejects Budget spree\n            2

# %%
df.groupby('category').filename.count().plot.bar(ylim=0)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english')

features = tfidf.fit_transform(df.content).toarray()
labels = df.category_id
features.shape
# Out:
# (2225, 14415)

# %%
from sklearn.feature_selection import chi2

N = 3
for category, category_id in sorted(category_to_id.items()):
  features_chi2 = chi2(features, labels == category_id)
  indices = np.argsort(features_chi2[0])
  feature_names = np.array(tfidf.get_feature_names())[indices]
  unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
  bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
  print("# '{}':".format(category))
  print("  . Most correlated unigrams:\n       . {}".format('\n       . '.join(unigrams[-N:])))
  print("  . Most correlated bigrams:\n       . {}".format('\n       . '.join(bigrams[-N:])))
# Out:
# # 'business':
#   . Most correlated unigrams:
#        . oil
#        . growth
#        . shares
#   . Most correlated bigrams:
#        . analysts said
#        . economic growth
#        . stock market
# # 'entertainment':
#   . Most correlated unigrams:
#        . singer
#        . actor
#        . film
#   . Most correlated bigrams:
#        . los angeles
#        . film festival
#        . box office
# # 'politics':
#   . Most correlated unigrams:
#        . blair
#        . election
#        . labour
#   . Most correlated bigrams:
#        . prime minister
#        . tony blair
#        . mr blair
# # 'sport':
#   . Most correlated unigrams:
#        . coach
#        . match
#        . cup
#   . Most correlated bigrams:
#        . grand slam
#        . australian open
#        . champions league
# # 'tech':
#   . Most correlated unigrams:
#        . technology
#        . software
#        . users
#   . Most correlated bigrams:
#        . anti virus
#        . mobile phones
#        . mobile phone

# %%
from sklearn.manifold import TSNE
import numpy as np
# Sampling a subset of our dataset because t-SNE is computationally expensive
SAMPLE_SIZE = int(len(features) * 0.3)
np.random.seed(0)
indices = np.random.choice(range(len(features)), size=SAMPLE_SIZE, replace=False)
projected_features = TSNE(n_components=2, random_state=0).fit_transform(features[indices])
colors = ['pink', 'green', 'midnightblue', 'orange', 'darkgrey']
for category, category_id in sorted(category_to_id.items()):
    points = projected_features[(labels[indices] == category_id).values]
    plt.scatter(points[:, 0], points[:, 1], s=30, c=colors[category_id], label=category)
plt.title("tf-idf feature vector for each article, projected on 2 dimensions.",
          fontdict=dict(fontsize=15))
plt.legend()

# %%
df[df.title.str.contains('Arsenal')]
# Out:
#                                                 content  category filename  \
# 449   Arsenal 'may seek full share listing'\n \n Ars...  business  271.txt
# 1459  Edu blasts Arsenal\n \n Arsenal's Brazilian mi...     sport  211.txt
# 1541  Chelsea hold Arsenal\n \n A gripping game betw...     sport  246.txt
# 1559  Campbell rescues Arsenal\n \n Sol Campbell pro...     sport  268.txt
# 1703  Mourinho takes swipe at Arsenal\n \n Chelsea b...     sport  280.txt
# 1764  Wenger dejected as Arsenal slump\n \n Arsenal ...     sport  157.txt
# 1773  Arsenal through on penalties\n \n Arsenal win ...     sport  163.txt
#
#                                         title  category_id
# 449   Arsenal 'may seek full share listing'\n            0
# 1459                     Edu blasts Arsenal\n            3
# 1541                   Chelsea hold Arsenal\n            3
# 1559               Campbell rescues Arsenal\n            3
# 1703        Mourinho takes swipe at Arsenal\n            3
# 1764       Wenger dejected as Arsenal slump\n            3
# 1773           Arsenal through on penalties\n            3

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB

from sklearn.model_selection import cross_val_score


models = [
    RandomForestClassifier(n_estimators=200, max_depth=3, random_state=0),
    MultinomialNB(),
    LogisticRegression(random_state=0),
]
CV = 5
cv_df = pd.DataFrame(index=range(CV * len(models)))
entries = []
for model in models:
  model_name = model.__class__.__name__
  accuracies = cross_val_score(model, features, labels, scoring='accuracy', cv=CV)
  for fold_idx, accuracy in enumerate(accuracies):
    entries.append((model_name, fold_idx, accuracy))
cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])
# Out:
# /home/saddamhussain/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/saddamhussain/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /home/saddamhussain/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/saddamhussain/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /home/saddamhussain/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/saddamhussain/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /home/saddamhussain/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/saddamhussain/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /home/saddamhussain/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/saddamhussain/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
import seaborn as sns
sns.boxplot(x='model_name', y='accuracy', data=cv_df)
sns.stripplot(x='model_name', y='accuracy', data=cv_df, 
              size=8, jitter=True, edgecolor="gray", linewidth=2)

# %%
cv_df.groupby('model_name').accuracy.mean()
# Out:
# model_name
# LogisticRegression        0.977090
# MultinomialNB             0.972156
# RandomForestClassifier    0.826075
# Name: accuracy, dtype: float64

# %%
from sklearn.model_selection import train_test_split

model = LogisticRegression(random_state=0)

X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(features, labels, df.index, test_size=0.33, random_state=0)
model.fit(X_train, y_train)
y_pred_proba = model.predict_proba(X_test)
y_pred = model.predict(X_test)
# Out:
# /home/saddamhussain/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/saddamhussain/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

conf_mat = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mat, annot=True, fmt='d',
            xticklabels=category_id_df.category.values, yticklabels=category_id_df.category.values)
plt.ylabel('Actual')
plt.xlabel('Predicted')
# Out:
# Text(0.5, 15.0, 'Predicted')

# %%
from IPython.display import display

for predicted in category_id_df.category_id:
  for actual in category_id_df.category_id:
    if predicted != actual and conf_mat[actual, predicted] >= 2:
      print("'{}' predicted as '{}' : {} examples.".format(id_to_category[actual], id_to_category[predicted], conf_mat[actual, predicted]))
      display(df.loc[indices_test[(y_test == actual) & (y_pred == predicted)]][['title', 'content']])
      print('')
# Out:
# 'politics' predicted as 'business' : 2 examples.
#                                   title  \
# 1001  Report attacks defence spending\n
# 1260         EU fraud clampdown urged\n
#
#                                                 content
# 1001  Report attacks defence spending\n \n The Minis...
# 1260  EU fraud clampdown urged\n \n EU member states...
# 'tech' predicted as 'business' : 3 examples.
#                                    title  \
# 1846  China 'ripe' for media explosion\n
# 1999   US blogger fired by her airline\n
# 2064   US blogger fired by her airline\n
#
#                                                 content
# 1846  China 'ripe' for media explosion\n \n Asia is ...
# 1999  US blogger fired by her airline\n \n A US airl...
# 2064  US blogger fired by her airline\n \n A US airl...
# 'tech' predicted as 'entertainment' : 2 examples.
#                                    title  \
# 1924   Half-Life 2 sweeps Bafta awards\n
# 1986  BBC leads interactive Bafta wins\n
#
#                                                 content
# 1924  Half-Life 2 sweeps Bafta awards\n \n PC first ...
# 1986  BBC leads interactive Bafta wins\n \n The BBC ...
# 'business' predicted as 'politics' : 2 examples.
#                                    title  \
# 135  Ban on forced retirement under 65\n
# 298         Salary scandal in Cameroon\n
#
#                                                content
# 135  Ban on forced retirement under 65\n \n Employe...
# 298  Salary scandal in Cameroon\n \n Cameroon says ...
# 'business' predicted as 'tech' : 4 examples.
#                                    title  \
# 195    Card fraudsters 'targeting web'\n
# 300   BT offers equal access to rivals\n
# 82     Making your office work for you\n
# 479  Brussels raps mobile call charges\n
#
#                                                content
# 195  Card fraudsters 'targeting web'\n \n New safeg...
# 300  BT offers equal access to rivals\n \n BT has m...
# 82   Making your office work for you\n \n Our missi...
# 479  Brussels raps mobile call charges\n \n The Eur...
# 'politics' predicted as 'tech' : 2 examples.
#                                   title  \
# 964   Game warnings 'must be clearer'\n
# 1187  UK firms 'embracing e-commerce'\n
#
#                                                 content
# 964   Game warnings 'must be clearer'\n \n Violent v...
# 1187  UK firms 'embracing e-commerce'\n \n UK firms ...

# %%
model.fit(features, labels)
# Out:
# /home/saddamhussain/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/saddamhussain/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=0, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
df[df.content.str.lower().str.contains('news website')].category.value_counts()
# Out:
# tech             69
# politics          8
# entertainment     7
# business          1
# Name: category, dtype: int64

# %%
texts = ["Trump then accused them of being racist, said they hate America",
         "Ronaldo scores a magnificent goal for the his team.",
         "Merryweather mercenaries are sent on another mission, as government oversight groups call for new sanctions.",
         "Beyoncé releases a new album, tops the charts in all of south-east Asia!",
         "You won't guess what the latest trend in data analysis is!"]
text_features = tfidf.transform(texts)
predictions = model.predict(text_features)
for text, predicted in zip(texts, predictions):
  print('"{}"'.format(text))
  print("  - Predicted as: '{}'".format(id_to_category[predicted]))
  print("")
# Out:
# "Trump then accused them of being racist, said they hate America"
#   - Predicted as: 'business'
#
# "Ronaldo scores a magnificent goal for the his team."
#   - Predicted as: 'sport'
#
# "Merryweather mercenaries are sent on another mission, as government oversight groups call for new sanctions."
#   - Predicted as: 'politics'
#
# "Beyoncé releases a new album, tops the charts in all of south-east Asia!"
#   - Predicted as: 'entertainment'
#
# "You won't guess what the latest trend in data analysis is!"
#   - Predicted as: 'tech'
